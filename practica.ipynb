# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib
# !pip install selenium
# !pip install pandas
# Out:
# Requirement already satisfied: requests in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: beautifulsoup4 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.6)
# Collecting lxml
#   Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Downloading lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/3.8 MB 7.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 7.0 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 4.7 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.0
# Collecting html5lib
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from html5lib) (0.5.1)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# Collecting selenium
#   Using cached selenium-4.26.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\tools\manim\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Using cached selenium-4.26.1-py3-none-any.whl (9.7 MB)
# Using cached trio-0.27.0-py3-none-any.whl (481 kB)
# Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, pysocks, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.26.1 sortedcontainers-2.4.0 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
# Requirement already satisfied: pandas in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\tools\manim\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\james\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests as req
from bs4 import BeautifulSoup

#google

url = "https://intranet.pronabec.edu.pe/Subvenciones/ReporteSubvenciones"
returns = req.get(url)
response = returns.text
print(response)

lois = BeautifulSoup(response, "html.parser")
print(lois)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta name="description" content="Intranet de estudios en el Perú, estudios en el extranjero, Intranet del beneficiario">
#     <meta name="author" content="PRONABEC">
#     <link rel="icon" type="image/png" href="https://www.pronabec.gob.pe/wp-content/uploads/2020/02/pronabec-favicon-final-36x36.png" />
#     <title>Acceso al sistema | Intranet del beneficiario</title>
#
#     <link href="/Content/themes/nuna_int/css/bootstrap.min.css" rel="stylesheet" />
#
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans|Quicksand" rel="stylesheet">
#     <link rel="stylesheet" href="/Content/themes/nuna_int/fontawesome/css/all.css">
#
#     <link href="/Content/themes/nuna_int/css/style_login.css" rel="stylesheet">
#     <link href="/Content/themes/nuna_int/plugins/alertifyjs/css/alertify.css" rel="stylesheet" />
#     <link href="/Content/themes/nuna_int/plugins/alertifyjs/css/themes/bootstrap.css?f=202003171852" rel="stylesheet" />
#
#
#
#
#     <style>
#         .btn-danger {
#             color: #fff;
#             background-color: #f94199 !important;
#             border-color: #f94199 !important;
#         }
#
#             .btn-danger:hover {
#                 background-color: #E71D73 !important;
#             }
#     </style>
# </head>
# <body>
#
#
# <!-- /.container -->
# <div class="container_row">
#     <div class="col-12 p-0" style="position:absolute;top:12%;">
#         <div class="container_form mx-auto">
#             <div class="box_form">
#                 <div class="col-12 p-0">
#                     <figure class="text-center">
#                         <img src="https://www.pronabec.gob.pe/wp-content/uploads/2020/02/cropped-Pronabec-Logo-2020-230x44.png" class="img-fluid mx-auto" alt="Logo Pronabec">
#                     </figure>
#                     <figure class="text-center">
#                         <img src="/Content/themes/nuna_int/img/logobeneficiario.png" style="max-width:300px!important;" class="img-fluid mx-auto" alt="Logo Pronabec">
#                     </figure>
#                     <!--<h2 class="text-center">INTRANET DEL BENEFICIARIO</h2>-->
# <form action="/?ReturnUrl=%2FSubvenciones%2FReporteSubvenciones" class="form-signin" id="login" method="post"><input name="__RequestVerificationToken" type="hidden" value="cGzSYGHBkJkC624m7Qeigri7FINxtp0dXlrAk4nScomlvBUy5l1_k0PTQiTrSt9pYLeIo5dLqYvJ458bxw_Bp5115u6uj1M6O-n6nu0sgzk1" />                        <div class="form-group">
#                             <label class="sr-only" for="user">Usuario</label>
#                             <div class="input-group mb-2">
#                                 <div class="input-group-prepend red">
#                                     <div class="input-group-text login_input">
#                                         <i class="fas fa-user"></i>
#                                     </div>
#                                 </div>
#                                 <input autocomplete="off" autofocus="True" class="form-control login_input" data-val="true" data-val-required="El campo UserName es obligatorio." id="UserName" maxlength="40" name="UserName" placeholder="Usuario" required="True" type="text" value="" />
#                             </div>
#                         </div>
#                         <div class="form-group">
#                             <label class="sr-only" for="pass">Contraseña</label>
#                             <div class="input-group mb-2">
#                                 <div class="input-group-prepend">
#                                     <div class="input-group-text login_input">
#                                         <i class="fas fa-lock"></i>
#                                     </div>
#                                 </div>
#                                 <input class="form-control login_input" data-val="true" data-val-required="El campo Password es obligatorio." id="Password" maxlength="40" name="Password" placeholder="Contraseña" required="True" type="password" />
#
#                                 <div class="input-group-append">
#                                     <div class="input-group-text login_input pt-0">
#                                         <i class="fa fa-fw fa-eye field-icon toggle-password" toggle="#password-field"></i>
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#                         <div class="form-group box_button">
#                             <button type="submit" class="btn btn_login"><i class="fas fa-sign-in-alt"></i> Ingresar</button>
#                             <div class="box_pass">
#                                 <a href="#" class="" id="#">¿Olvidaste tu contraseña?</a>
#                             </div>
#                         </div>
# </form>                    <form id="recovery" class="hideForm">
#
#                         <div class="form-group">
#                             <label id="lblRecuperacion" hidden></label>
#                         </div>
#
#                         <div class="form-group">
#                             <label class="sr-only" for="dni">Número de DNI / Carnet de Extranjería</label>
#                             <div class="input-group mb-2">
#                                 <div class="input-group-prepend red">
#                                     <div class="input-group-text login_input">
#                                         <i class="fas fa-user"></i>
#                                     </div>
#                                 </div>
#                                 <input type="text" class="form-control login_input" id="dni" name="dni" autocomplete="off" placeholder="DNI / Carnet de Extranjería" required>
#                             </div>
#                         </div>
#                         <div class="form-group">
#                             <label class="sr-only" for="">Fecha de nacimiento</label>
#                             <div class="input-group mb-2">
#                                 <div class="input-group-prepend">
#                                     <div class="input-group-text login_input">
#                                         <i class="fas fa-lock"></i>
#                                     </div>
#                                 </div>
#                                 <input id="fechaNacimiento" name="fechaNacimiento" type="text" class="form-control login_input" autocomplete="off" placeholder="Fecha de nacimiento" required pattern="(0[1-9]|[12][0-9]|3[01])[- /.](0[1-9]|1[012])[- /.](19|20)\d\d">
#                             </div>
#                         </div>
#                         <div class="form-group box_button">
#                             <button type="button" class="btn btn-danger btn_cancelar"><i class="fa fa-arrow-circle-left"></i> Cancelar</button>
#                             <button type="submit" data-loading-text="<i class='fa fa-spinner fa-spin'></i> Por favor espere ..." class="btn btn-info" id="restablecer_acceso">Recupera <i class="fas fa-arrow-circle-right"></i></button>
#                         </div>
#                     </form>
#                     <div class="bar">
#                         <img src="/Content/themes/nuna_int/img/icono_lineas_colores.png" class="img-fluid" alt="PRONABEC">
#                     </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="consulta">
#             <span><div class="box_ico"><i class="fas fa-phone"></i></div> <div class="telefonos tel"> 0800-00018</div></span>
#             <span><div class="box_ico"><i class="fas fa-phone"></i></div> <div class="telefonos tel"> (01) 612-8230</div></span>
#             <span><div class="box_ico"><i class="fab fa-whatsapp"></i></div> <a href="https://api.whatsapp.com/send?phone=51914121106" target="_blank" class="telefonos"> 914 121 106</a></span>
#         </div>
#
#         <hr class="separation">
#
#         <div class="social_media">
#             <div class="social mx-auto">
#                 <a href="https://www.facebook.com/PRONABEC" target="_blank" rel="noopener noreferrer"><i class="fab fa-facebook-f"></i></a>
#                 <a href="https://twitter.com/pronabec" target="_blank" rel="noopener noreferrer"><i class="fab fa-twitter"></i></a>
#                 <a href="https://www.instagram.com/pronabec" target="_blank" rel="noopener noreferrer"><i class="fab fa-instagram"></i></a>
#                 <a href="https://pe.linkedin.com/company/pronabec" target="_blank" rel="noopener noreferrer"><i class="fab fa-linkedin-in"></i></a>
#                 <a href="https://www.youtube.com/user/Beca18Oficial/videos" target="_blank" rel="noopener noreferrer"><i class="fab fa-youtube"></i></a>
#             </div>
#         </div>
#     </div>
# </div>
#
#     <script src="/Content/themes/nuna_int/js/jquery.3.3.1.js"></script>
#     <script src="/Content/themes/nuna_int/js/bootstrap.min.js"></script>
#     <script src="/Content/themes/nuna_int/plugins/inputmask/jquery.inputmask.bundle.min.js"></script>
#     <script src="/Content/themes/nuna_int/plugins/alertifyjs/alertify.min.js"></script>
#     <script src="/Content/themes/nuna_int/plugins/alertifyjs/alert.js?f=202003171852"></script>
#
#     <script src="/Scripts/App/Facebook/auth.js"></script>
#     <script src="/Scripts/App/Sibec.js?f=202003171852"></script>
#
#
#     <script src="/Scripts/App/Account/Login.js"></script>
#     <script>
#         url_ = "https://intranet.pronabec.edu.pe";
#         errorAutenticacion_ = "";
#         appLogin.init();
#
#         (function ($) {
#             $.fn.button = function (action) {
#                 if (action === 'loading' && this.data('loading-text')) {
#                     this.data('original-text', this.html()).html(this.data('loading-text')).prop('disabled', true);
#                 }
#                 if (action === 'reset' && this.data('original-text')) {
#                     this.html(this.data('original-text')).prop('disabled', false);
#                 }
#             };
#         }(jQuery));
#     </script>
#
# </body>
# </html>
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Intranet de estudios en el Perú, estudios en el extranjero, Intranet del beneficiario" name="description"/>
# <meta content="PRONABEC" name="author"/>
# <link href="https://www.pronabec.gob.pe/wp-content/uploads/2020/02/pronabec-favicon-final-36x36.png" rel="icon" type="image/png"/>
# <title>Acceso al sistema | Intranet del beneficiario</title>
# <link href="/Content/themes/nuna_int/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans|Quicksand" rel="stylesheet"/>
# <link href="/Content/themes/nuna_int/fontawesome/css/all.css" rel="stylesheet"/>
# <link href="/Content/themes/nuna_int/css/style_login.css" rel="stylesheet"/>
# <link href="/Content/themes/nuna_int/plugins/alertifyjs/css/alertify.css" rel="stylesheet">
# <link href="/Content/themes/nuna_int/plugins/alertifyjs/css/themes/bootstrap.css?f=202003171852" rel="stylesheet">
# <style>
#         .btn-danger {
#             color: #fff;
#             background-color: #f94199 !important;
#             border-color: #f94199 !important;
#         }
#
#             .btn-danger:hover {
#                 background-color: #E71D73 !important;
#             }
#     </style>
# </link></link></head>
# <body>
# <!-- /.container -->
# <div class="container_row">
# <div class="col-12 p-0" style="position:absolute;top:12%;">
# <div class="container_form mx-auto">
# <div class="box_form">
# <div class="col-12 p-0">
# <figure class="text-center">
# <img alt="Logo Pronabec" class="img-fluid mx-auto" src="https://www.pronabec.gob.pe/wp-content/uploads/2020/02/cropped-Pronabec-Logo-2020-230x44.png"/>
# </figure>
# <figure class="text-center">
# <img alt="Logo Pronabec" class="img-fluid mx-auto" src="/Content/themes/nuna_int/img/logobeneficiario.png" style="max-width:300px!important;"/>
# </figure>
# <!--<h2 class="text-center">INTRANET DEL BENEFICIARIO</h2>-->
# <form action="/?ReturnUrl=%2FSubvenciones%2FReporteSubvenciones" class="form-signin" id="login" method="post"><input name="__RequestVerificationToken" type="hidden" value="cGzSYGHBkJkC624m7Qeigri7FINxtp0dXlrAk4nScomlvBUy5l1_k0PTQiTrSt9pYLeIo5dLqYvJ458bxw_Bp5115u6uj1M6O-n6nu0sgzk1"/> <div class="form-group">
# <label class="sr-only" for="user">Usuario</label>
# <div class="input-group mb-2">
# <div class="input-group-prepend red">
# <div class="input-group-text login_input">
# <i class="fas fa-user"></i>
# </div>
# </div>
# <input autocomplete="off" autofocus="True" class="form-control login_input" data-val="true" data-val-required="El campo UserName es obligatorio." id="UserName" maxlength="40" name="UserName" placeholder="Usuario" required="True" type="text" value=""/>
# </div>
# </div>
# <div class="form-group">
# <label class="sr-only" for="pass">Contraseña</label>
# <div class="input-group mb-2">
# <div class="input-group-prepend">
# <div class="input-group-text login_input">
# <i class="fas fa-lock"></i>
# </div>
# </div>
# <input class="form-control login_input" data-val="true" data-val-required="El campo Password es obligatorio." id="Password" maxlength="40" name="Password" placeholder="Contraseña" required="True" type="password"/>
# <div class="input-group-append">
# <div class="input-group-text login_input pt-0">
# <i class="fa fa-fw fa-eye field-icon toggle-password" toggle="#password-field"></i>
# </div>
# </div>
# </div>
# </div>
# <div class="form-group box_button">
# <button class="btn btn_login" type="submit"><i class="fas fa-sign-in-alt"></i> Ingresar</button>
# <div class="box_pass">
# <a class="" href="#" id="#">¿Olvidaste tu contraseña?</a>
# </div>
# </div>
# </form> <form class="hideForm" id="recovery">
# <div class="form-group">
# <label hidden="" id="lblRecuperacion"></label>
# </div>
# <div class="form-group">
# <label class="sr-only" for="dni">Número de DNI / Carnet de Extranjería</label>
# <div class="input-group mb-2">
# <div class="input-group-prepend red">
# <div class="input-group-text login_input">
# <i class="fas fa-user"></i>
# </div>
# </div>
# <input autocomplete="off" class="form-control login_input" id="dni" name="dni" placeholder="DNI / Carnet de Extranjería" required="" type="text"/>
# </div>
# </div>
# <div class="form-group">
# <label class="sr-only" for="">Fecha de nacimiento</label>
# <div class="input-group mb-2">
# <div class="input-group-prepend">
# <div class="input-group-text login_input">
# <i class="fas fa-lock"></i>
# </div>
# </div>
# <input autocomplete="off" class="form-control login_input" id="fechaNacimiento" name="fechaNacimiento" pattern="(0[1-9]|[12][0-9]|3[01])[- /.](0[1-9]|1[012])[- /.](19|20)\d\d" placeholder="Fecha de nacimiento" required="" type="text"/>
# </div>
# </div>
# <div class="form-group box_button">
# <button class="btn btn-danger btn_cancelar" type="button"><i class="fa fa-arrow-circle-left"></i> Cancelar</button>
# <button class="btn btn-info" data-loading-text="&lt;i class='fa fa-spinner fa-spin'&gt;&lt;/i&gt; Por favor espere ..." id="restablecer_acceso" type="submit">Recupera <i class="fas fa-arrow-circle-right"></i></button>
# </div>
# </form>
# <div class="bar">
# <img alt="PRONABEC" class="img-fluid" src="/Content/themes/nuna_int/img/icono_lineas_colores.png"/>
# </div>
# </div>
# </div>
# </div>
# <div class="consulta">
# <span><div class="box_ico"><i class="fas fa-phone"></i></div> <div class="telefonos tel"> 0800-00018</div></span>
# <span><div class="box_ico"><i class="fas fa-phone"></i></div> <div class="telefonos tel"> (01) 612-8230</div></span>
# <span><div class="box_ico"><i class="fab fa-whatsapp"></i></div> <a class="telefonos" href="https://api.whatsapp.com/send?phone=51914121106" target="_blank"> 914 121 106</a></span>
# </div>
# <hr class="separation"/>
# <div class="social_media">
# <div class="social mx-auto">
# <a href="https://www.facebook.com/PRONABEC" rel="noopener noreferrer" target="_blank"><i class="fab fa-facebook-f"></i></a>
# <a href="https://twitter.com/pronabec" rel="noopener noreferrer" target="_blank"><i class="fab fa-twitter"></i></a>
# <a href="https://www.instagram.com/pronabec" rel="noopener noreferrer" target="_blank"><i class="fab fa-instagram"></i></a>
# <a href="https://pe.linkedin.com/company/pronabec" rel="noopener noreferrer" target="_blank"><i class="fab fa-linkedin-in"></i></a>
# <a href="https://www.youtube.com/user/Beca18Oficial/videos" rel="noopener noreferrer" target="_blank"><i class="fab fa-youtube"></i></a>
# </div>
# </div>
# </div>
# </div>
# <script src="/Content/themes/nuna_int/js/jquery.3.3.1.js"></script>
# <script src="/Content/themes/nuna_int/js/bootstrap.min.js"></script>
# <script src="/Content/themes/nuna_int/plugins/inputmask/jquery.inputmask.bundle.min.js"></script>
# <script src="/Content/themes/nuna_int/plugins/alertifyjs/alertify.min.js"></script>
# <script src="/Content/themes/nuna_int/plugins/alertifyjs/alert.js?f=202003171852"></script>
# <script src="/Scripts/App/Facebook/auth.js"></script>
# <script src="/Scripts/App/Sibec.js?f=202003171852"></script>
# <script src="/Scripts/App/Account/Login.js"></script>
# <script>
#         url_ = "https://intranet.pronabec.edu.pe";
#         errorAutenticacion_ = "";
#         appLogin.init();
#
#         (function ($) {
#             $.fn.button = function (action) {
#                 if (action === 'loading' && this.data('loading-text')) {
#                     this.data('original-text', this.html()).html(this.data('loading-text')).prop('disabled', true);
#                 }
#                 if (action === 'reset' && this.data('original-text')) {
#                     this.html(this.data('original-text')).prop('disabled', false);
#                 }
#             };
#         }(jQuery));
#     </script>
# </body>
# </html>
